# %% [markdown]
# <a href="https://colab.research.google.com/github/rafajacomel/phd_ita/blob/main/pytorch_sentiment_analysis_cnn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("test")
# Out:
# test
